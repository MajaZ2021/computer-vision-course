# %% [markdown]
# <a href="https://colab.research.google.com/github/MajaZ2021/computer-vision-course/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### TEmplate

# %%
print('Hello colab')
# Out:
# Hello colab
